# %% [markdown]
# # Doing some EDL on the two datasets

# %%
import pandas as pd

df_seed = pd.read_csv(r'data/Ephesis_export-7.csv', delimiter=';') # importing the seed data frame that has 3 different seed types

df_seed.head()
# Out:
#   Lot Number Accession Number Accession Name                      itk  \
# 0    RE99006            22563        RE99006                  treated
# 1    CF99003            29112        CF99003               low inputs
# 2     Tremie             7043         TREMIE               low inputs
# 3    EM99021            37777        EM99021  untreated, no fungicide
# 4    RE99007            22564        RE99007               low inputs
#
#                        Trial Name        Trial Site  REPLICATION  X(m)  Y(m)  \
# 0  BTH_Clermont-Ferrand_2000_SetA  Clermont-Ferrand            1   NaN   NaN
# 1             BTH_Dijon_2000_SetA             Dijon            1   NaN   NaN
# 2             BTH_Dijon_2000_SetA             Dijon            1   NaN   NaN
# 3         BTH_Le_Moulon_2000_SetA         Le Moulon            2   NaN   NaN
# 4         BTH_Le_Moulon_2000_SetA         Le Moulon            1   NaN   NaN
#
#    Campaign  ...  ps: Test weight Date [ps]  sept: Septoria score Date [sept]  \
# ...

# %%
df_seed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81434 entries, 0 to 81433
# Data columns (total 27 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Lot Number                                 81434 non-null  object
#  1   Accession Number                           81434 non-null  object
#  2   Accession Name                             81434 non-null  object
#  3   itk                                        81434 non-null  object
#  4   Trial Name                                 81434 non-null  object
#  5   Trial Site                                 81434 non-null  object
#  6   REPLICATION                                81434 non-null  int64
#  7   X(m)                                       0 non-null      float64
#  8   Y(m)                                       0 non-null      float64
#  9   Campaign                                   81434 non-null  int64
# ...

# %%
df_crop_rec = pd.read_csv(r'data/Ephesis_export-8.csv', delimiter=';') # This is a data set with other information about a lot of different crops

df_crop_rec
# Out:
#        Lot Number Accession Number Accession Name                      itk  \
# 0      HA1541.134       HA1541.134     HA1541.134                  treated
# 1         CF99007            32316        CF99007               low inputs
# 2          Tremie             7043         TREMIE  untreated, no fungicide
# 3        SOISSONS             6607       SOISSONS                  treated
# 4         RE99016            29193        RE99016                  treated
# ...           ...              ...            ...                      ...
# 52874     AO15011          AO15011        AO15011                      NaN
# 52875     AO15025          AO15025        AO15025           faible intrant
# 52876     AO13015          AO13015        AO13015                   traite
# 52877     AO14039          AO14039        AO14039                   traite
# 52878     RE13004            39433        RE13004           faible intrant
#
# ...

# %%
df_crop_rec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52879 entries, 0 to 52878
# Columns: 112 entries, Lot Number to Date [volD]
# dtypes: float64(72), int64(1), object(39)
# memory usage: 45.2+ MB
