# %% [markdown]
# # Doing some EDL on the two datasets

# %%
import pandas as pd

df_seed = pd.read_csv(r'data\Ephesis_export-7.csv') # importing the seed data frame that has 3 different seed types

df_seed.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df_seed = pd.read_csv(r'data\Ephesis_export-7.csv') # importing the seed data frame that has 3 different seed types
#       5 df_seed.head()
#
# ...

# %%
df_seed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       210 non-null    float64
#  1   P       210 non-null    float64
#  2   C       210 non-null    float64
#  3   LK      210 non-null    float64
#  4   WK      210 non-null    float64
#  5   A_Coef  210 non-null    float64
#  6   LKG     210 non-null    float64
#  7   target  210 non-null    int64
# dtypes: float64(7), int64(1)
# memory usage: 13.2 KB

# %%
df_crop_rec = pd.read_csv(r'data\Crop_recommendation.csv') # This is a data set with other information about a lot of different crops

df_crop_rec
# Out:
#       Nitrogen  phosphorus  potassium  temperature   humidity        ph  \
# 0           90          42         43    20.879744  82.002744  6.502985
# 1           85          58         41    21.770462  80.319644  7.038096
# 2           60          55         44    23.004459  82.320763  7.840207
# 3           74          35         40    26.491096  80.158363  6.980401
# 4           78          42         42    20.130175  81.604873  7.628473
# ...        ...         ...        ...          ...        ...       ...
# 2195       107          34         32    26.774637  66.413269  6.780064
# 2196        99          15         27    27.417112  56.636362  6.086922
# 2197       118          33         30    24.131797  67.225123  6.362608
# 2198       117          32         34    26.272418  52.127394  6.758793
# 2199       104          18         30    23.603016  60.396475  6.779833
#
#         rainfall   label  Unnamed: 8  Unnamed: 9
# 0     202.935536    rice         NaN         NaN
# ...
